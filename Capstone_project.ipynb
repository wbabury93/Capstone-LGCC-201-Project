# %% [markdown]
# <a href="https://colab.research.google.com/github/wbabury93/Capstone-LGCC-201-Project/blob/main/Capstone_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# For my Capstone project I decided to test if there is an impact on college professor's salary based off their title.

# %%
import pandas as pd

# %%
df=pd.DataFrame()

# %%
df= pd.read_csv('https://raw.githubusercontent.com/trendct/datasets/master/0415-ct-professors/ct-professor-salaries.csv')

# %%
df.count()
# Out:
# College                38
# Average All Pay        38
# Average Professor      37
# Associate Professor    37
# Assistant Professor    35
# Lecturer               33
# City                   38
# dtype: int64

# %%
df.tail()
# Out:
#                                  College  ...           City
# 33            University of Saint Joseph  ...  West Hartford
# 34                US Coast Guard Academy  ...     New London
# 35                   Wesleyan University  ...     Middletown
# 36  Western Connecticut State University  ...        Danbury
# 37                       Yale University  ...      New Haven
#
# [5 rows x 7 columns]

# %%
df.head()
# Out:
#                                 College  Average All Pay  ...  Lecturer         City
# 0               Albertus Magnus College            68409  ...       NaN    New Haven
# 1           Asnuntuck Community College            62190  ...   45315.0      Enfield
# 2             Capital Community College            63225  ...   48195.0     Hartford
# 3  Central Connecticut State University            76617  ...   52344.0  New Britain
# 4                   Connecticut College            86166  ...   63000.0   New London
#
# [5 rows x 7 columns]

# %%
df.loc[0:8]
# Out:
#                                 College  Average All Pay  ...  Lecturer         City
# 0               Albertus Magnus College            68409  ...       NaN    New Haven
# 1           Asnuntuck Community College            62190  ...   45315.0      Enfield
# 2             Capital Community College            63225  ...   48195.0     Hartford
# 3  Central Connecticut State University            76617  ...   52344.0  New Britain
# 4                   Connecticut College            86166  ...   63000.0   New London
# 5  Eastern Connecticut State University            72819  ...   48357.0  Willimantic
# 6                  Fairfield University            91926  ...   75015.0    Fairfield
# 7             Gateway Community College            69966  ...   52884.0    New Haven
# 8                     Hartford Seminary            54387  ...   30987.0     Hartford
#
# [9 rows x 7 columns]

# %%
df.drop_duplicates()
# Out:
#                                        College  ...           City
# 0                      Albertus Magnus College  ...      New Haven
# 1                  Asnuntuck Community College  ...        Enfield
# 2                    Capital Community College  ...       Hartford
# 3         Central Connecticut State University  ...    New Britain
# 4                          Connecticut College  ...     New London
# 5         Eastern Connecticut State University  ...    Willimantic
# 6                         Fairfield University  ...      Fairfield
# 7                    Gateway Community College  ...      New Haven
# 8                            Hartford Seminary  ...       Hartford
# 9                  Holy Apostles College & Sem  ...       Cromwell
# 10                Housatonic Community College  ...     Bridgeport
# 11                 Lincoln College New England  ...    Southington
# 12               LymeAcademy College Fine Arts  ...       Old Lyme
# ...

# %%
df.loc[0:7]
# Out:
#                                 College  Average All Pay  ...  Lecturer         City
# 0               Albertus Magnus College            68409  ...       NaN    New Haven
# 1           Asnuntuck Community College            62190  ...   45315.0      Enfield
# 2             Capital Community College            63225  ...   48195.0     Hartford
# 3  Central Connecticut State University            76617  ...   52344.0  New Britain
# 4                   Connecticut College            86166  ...   63000.0   New London
# 5  Eastern Connecticut State University            72819  ...   48357.0  Willimantic
# 6                  Fairfield University            91926  ...   75015.0    Fairfield
# 7             Gateway Community College            69966  ...   52884.0    New Haven
#
# [8 rows x 7 columns]

# %% [markdown]
# I am trying to look for the best data to compare and use. For now, I will use the first seven colleges and based off the first seven colleges I can see if a professor's salary has any impact on their salary.

# %%
df.dropna()
df.head(8)
# Out:
#                                 College  Average All Pay  ...  Lecturer         City
# 0               Albertus Magnus College            68409  ...       NaN    New Haven
# 1           Asnuntuck Community College            62190  ...   45315.0      Enfield
# 2             Capital Community College            63225  ...   48195.0     Hartford
# 3  Central Connecticut State University            76617  ...   52344.0  New Britain
# 4                   Connecticut College            86166  ...   63000.0   New London
# 5  Eastern Connecticut State University            72819  ...   48357.0  Willimantic
# 6                  Fairfield University            91926  ...   75015.0    Fairfield
# 7             Gateway Community College            69966  ...   52884.0    New Haven
#
# [8 rows x 7 columns]

# %%
df.dropna(subset = ['Lecturer'])
df.head(10)
# Out:
#                                 College  Average All Pay  ...  Lecturer         City
# 0               Albertus Magnus College            68409  ...       NaN    New Haven
# 1           Asnuntuck Community College            62190  ...   45315.0      Enfield
# 2             Capital Community College            63225  ...   48195.0     Hartford
# 3  Central Connecticut State University            76617  ...   52344.0  New Britain
# 4                   Connecticut College            86166  ...   63000.0   New London
# 5  Eastern Connecticut State University            72819  ...   48357.0  Willimantic
# 6                  Fairfield University            91926  ...   75015.0    Fairfield
# 7             Gateway Community College            69966  ...   52884.0    New Haven
# 8                     Hartford Seminary            54387  ...   30987.0     Hartford
# 9           Holy Apostles College & Sem            29331  ...   10647.0     Cromwell
#
# [10 rows x 7 columns]

# %%
df.loc[1:10]
# Out:
#                                  College  ...         City
# 1            Asnuntuck Community College  ...      Enfield
# 2              Capital Community College  ...     Hartford
# 3   Central Connecticut State University  ...  New Britain
# 4                    Connecticut College  ...   New London
# 5   Eastern Connecticut State University  ...  Willimantic
# 6                   Fairfield University  ...    Fairfield
# 7              Gateway Community College  ...    New Haven
# 8                      Hartford Seminary  ...     Hartford
# 9            Holy Apostles College & Sem  ...     Cromwell
# 10          Housatonic Community College  ...   Bridgeport
#
# [10 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import numpy

# %%
plt.plot([1,10])
plt.title('Graph of Professors salaries')
# Out:
# Text(0.5, 1.0, 'Graph of Professors salaries')

# %% [markdown]
# In my conclusion after looking at ten different colleges I can conclude that a full time professor will likely make more money than an associate professor and so on. For a professor to make more they need to have a PHD which separates them from being a lecturer and need to be employeed full time by the college.
